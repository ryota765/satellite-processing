# %%
import sys

sys.path.remove('/usr/local/lib/python3.8/site-packages')
sys.path.append('/usr/local/lib/python3.7/site-packages')
# sys.path.append('/usr/local/lib/python3.9/site-packages')

# %%
import os
import glob
import shutil
import random
import datetime
import csv
import colorsys
import math
import xlrd

import pandas as pd
import pickle
from PIL import Image, ExifTags, ImageDraw, ImageFont
import numpy as np
from itertools import chain
import cv2
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from scipy.optimize import curve_fit
import seaborn as sns

# %% [markdown]
# # Preprocess geotiff image (~.img)

# %%
# merge 2 geo-tiff image (optional)
# python3 gdal_merge.py -init 255 -o out.img in1.img in2.img -co COMPRESS=DEFLATE

# Convert geo-tiff to npy array
# python3 parse_geotiff.py

# %%
test = np.load('out.npy')
print(test.shape)
plt.imshow(test[0])
# Out:
# (2, 321792, 24673)
# Error in callback <function flush_figures at 0x7f8b8ba88b00> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     115         # ignore the tracking, just draw and close all figures
#     116         try:
# --> 117             return show(True)
#     118         except Exception as e:
#     119             # safely show traceback if in IPython, else raise
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ...

# %%
test = np.load('/Users/ryotanomura/test.npy')
print(test.shape)
plt.imshow(test[0])
# Out:
# (1, 5400, 6396)

# %%
test = np.load('/Users/ryotanomura/test1.npy')
print(test.shape)
plt.imshow(test[0])
# Out:
# (1, 5500, 6396)

# %%
test = np.load('/Users/ryotanomura/test2.npy')
print(test.shape)
plt.imshow(test[0])
# Out:
# (1, 5400, 6296)

# %%
opt = np.load('/Users/ryotanomura/test_opt.npy') 
sar = np.load('/Users/ryotanomura/test_sar.npy') # sar will be in float32

# %%
print(opt.shape)
print(sar.shape)
# Out:
# (4, 8450, 8556)
# (4, 5600, 3200)

# %%
plt.imshow(a.transpose(1,2,0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
